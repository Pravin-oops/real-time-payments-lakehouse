# %%
import urllib.parse

# 1. Define AWS Credentials
aws_access_key = ""
aws_secret_key = ""
aws_bucket_name = "" 

# 2. Configure the Spark Session to use AWS S3
encoded_secret_key = urllib.parse.quote(aws_secret_key, safe="")

# 3. Inject the keys directly into the S3 connection string
s3_path = f"s3a://{aws_access_key}:{encoded_secret_key}@{aws_bucket_name}/raw_upi_data/"

print("✅ AWS Credentials Configured Successfully!")

# %%
display(dbutils.fs.ls(s3_path))
# to check files apprearing from s3 bucket
